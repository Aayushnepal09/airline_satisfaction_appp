# %% [markdown]
# # 03 — Experiments (with/without PCA) + Optional Hyperparameter Tuning
#
# This notebook sets up the **required experiment grid**:
#
# 1. Ridge, HGB, XGBoost, LightGBM **with and without PCA** (8 experiments)
# 2. Same 4 models with and without PCA **with hyperparameter tuning** (8 experiments)
#
# We evaluate using:
# - **3-fold CV F1** on the training set
# - F1 on the held-out test set
#
# > Note: To keep this notebook runnable locally without extra services, MLflow/DagsHub logging is optional. You can add it later.

# %%
# 03 — Train Models (With Optuna) + Log 8 Experiments to DagsHub/MLflow

from pathlib import Path
import json
import sqlite3
from datetime import datetime

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import f1_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier
import joblib

import optuna

# DagsHub + MLflow
import dagshub
dagshub.init(repo_owner='Aayushnepal09', repo_name='my-first-repo', mlflow=True)

import mlflow

SEED = 42
np.random.seed(SEED)

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

import sys
sys.path.append(str(PROJECT_ROOT))

DB_PATH = PROJECT_ROOT / "data" / "airline.db"
MODELS_DIR = PROJECT_ROOT / "models"
METRICS_DIR = PROJECT_ROOT / "models" / "metrics"

MODELS_DIR.mkdir(parents=True, exist_ok=True)
METRICS_DIR.mkdir(parents=True, exist_ok=True)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("DB_PATH:", DB_PATH, "exists=", DB_PATH.exists())
# Out:
# Initialized MLflow to track repo "Aayushnepal09/my-first-repo"
# Repository Aayushnepal09/my-first-repo initialized!
# PROJECT_ROOT: c:\Users\nepal\OneDrive\Desktop\airline_satisfaction_appp
# DB_PATH: c:\Users\nepal\OneDrive\Desktop\airline_satisfaction_appp\data\airline.db exists= True

# %% [markdown]
# ## Helper: run a single experiment

# %%
# Load training dataframe from the normalized DB (same join as NB02)
if not DB_PATH.exists():
    raise FileNotFoundError(
        f"Database not found at {DB_PATH}. Run 01_create_database.ipynb first."
    )

conn = sqlite3.connect(DB_PATH)

query = '''
SELECT
    p.gender,
    p.customer_type,
    p.age,
    t.type_of_travel,
    t.travel_class,
    t.flight_distance,
    s.inflight_wifi_service,
    s.departure_arrival_time_convenient,
    s.ease_of_online_booking,
    s.gate_location,
    s.food_and_drink,
    s.online_boarding,
    s.seat_comfort,
    s.inflight_entertainment,
    s.on_board_service,
    s.leg_room_service,
    s.baggage_handling,
    s.checkin_service,
    s.inflight_service,
    s.cleanliness,
    d.departure_delay_minutes,
    d.arrival_delay_minutes,
    sat.satisfaction_binary
FROM trip t
JOIN passenger p ON t.passenger_id = p.passenger_id
JOIN service_rating s ON s.trip_id = t.trip_id
JOIN delay d ON d.trip_id = t.trip_id
JOIN satisfaction sat ON sat.trip_id = t.trip_id
;
'''
df = pd.read_sql_query(query, conn)
conn.close()

TARGET = "satisfaction_binary"
X = df.drop(columns=[TARGET])
y = df[TARGET].astype(int)

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=SEED,
    stratify=y
)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

display(df.head())
print("Train:", X_train.shape, "Test:", X_test.shape)
# Out:
#    gender      customer_type  age   type_of_travel travel_class  \
# 0    Male     Loyal Customer   13  Personal Travel     Eco Plus
# 1    Male  disloyal Customer   25  Business travel     Business
# 2  Female     Loyal Customer   26  Business travel     Business
# 3  Female     Loyal Customer   25  Business travel     Business
# 4    Male     Loyal Customer   61  Business travel     Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    ease_of_online_booking  gate_location  ...  inflight_entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    on_board_service  leg_room_service  baggage_handling  checkin_service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    inflight_service  cleanliness  departure_delay_minutes  \
# 0                 5            5                       25
# 1                 4            1                        1
# 2                 4            5                        0
# 3                 4            2                       11
# 4                 3            3                        0
#
#    arrival_delay_minutes  satisfaction_binary
# 0                     18                    0
# 1                      6                    0
# 2                      0                    1
# 3                      9                    0
# 4                      0                    1
#
# [5 rows x 23 columns]
# Train: (83123, 22) Test: (20781, 22)

# %% [markdown]
# ## Run required experiments

# %%
# Preprocessing + estimator builders
from housing_pipeline import build_preprocessing

def build_pipeline_for_params(model_name: str, use_pca: bool, params: dict):
    preprocess = build_preprocessing(use_pca=use_pca)

    if model_name == "logreg":
        est = LogisticRegression(
            max_iter=3000,
            random_state=SEED,
            **params
        )
    elif model_name == "ridge":
        est = RidgeClassifier(
            random_state=SEED,
            **params
        )
    elif model_name == "hgb":
        est = HistGradientBoostingClassifier(
            random_state=SEED,
            **params
        )
    elif model_name == "rf":
        est = RandomForestClassifier(
            random_state=SEED,
            n_jobs=-1,
            **params
        )
    else:
        raise ValueError(f"Unknown model_name: {model_name}")

    return Pipeline([("preprocess", preprocess), ("model", est)])

def suggest_params(trial: optuna.Trial, model_name: str) -> dict:
    if model_name == "logreg":
        # liblinear supports l1/l2, lbfgs supports l2
        solver = trial.suggest_categorical("solver", ["liblinear", "lbfgs"])
        if solver == "liblinear":
            penalty = trial.suggest_categorical("penalty", ["l1", "l2"])
        else:
            penalty = "l2"
        C = trial.suggest_float("C", 1e-3, 50.0, log=True)
        return {"solver": solver, "penalty": penalty, "C": C}

    if model_name == "ridge":
        alpha = trial.suggest_float("alpha", 1e-3, 50.0, log=True)
        return {"alpha": alpha}

    if model_name == "hgb":
        learning_rate = trial.suggest_float("learning_rate", 0.01, 0.3, log=True)
        max_depth = trial.suggest_int("max_depth", 2, 10)
        max_leaf_nodes = trial.suggest_int("max_leaf_nodes", 15, 255)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 10, 200)
        l2_regularization = trial.suggest_float("l2_regularization", 1e-6, 10.0, log=True)
        max_iter = trial.suggest_int("max_iter", 100, 500)
        return {
            "learning_rate": learning_rate,
            "max_depth": max_depth,
            "max_leaf_nodes": max_leaf_nodes,
            "min_samples_leaf": min_samples_leaf,
            "l2_regularization": l2_regularization,
            "max_iter": max_iter,
        }

    if model_name == "rf":
        n_estimators = trial.suggest_int("n_estimators", 150, 600)
        max_depth = trial.suggest_int("max_depth", 3, 30)
        min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 10)
        max_features = trial.suggest_categorical("max_features", ["sqrt", "log2", None])
        return {
            "n_estimators": n_estimators,
            "max_depth": max_depth,
            "min_samples_split": min_samples_split,
            "min_samples_leaf": min_samples_leaf,
            "max_features": max_features,
        }

    raise ValueError(f"Unknown model_name: {model_name}")

# %% [markdown]
# ## Save the best pipeline as `global_best_model_optuna.pkl`
# (Notebook name kept from the starter repo; tuning here uses GridSearchCV by default.)

# %%
# Run 8 tuned experiments:
# 4 algorithms × (PCA on/off) × (Optuna tuning)

mlflow.set_experiment("airline_satisfaction_with_optuna")

EXPERIMENTS = []
for model_name in ["logreg", "ridge", "hgb", "rf"]:
    for use_pca in [False, True]:
        EXPERIMENTS.append(dict(model_name=model_name, use_pca=use_pca, tuned=True))

results = []
best = None  # track best by test_f1

def objective(trial: optuna.Trial, model_name: str, use_pca: bool) -> float:
    params = suggest_params(trial, model_name)
    pipe = build_pipeline_for_params(model_name, use_pca, params)

    scores = cross_val_score(
        pipe, X_train, y_train,
        cv=cv,
        scoring="f1",
        n_jobs=-1
    )
    return float(np.mean(scores))

# Keep trials reasonable for grading/runtime
TRIALS_BY_MODEL = {"logreg": 25, "ridge": 20, "hgb": 25, "rf": 20}

for exp in EXPERIMENTS:
    model_name = exp["model_name"]
    use_pca = exp["use_pca"]
    n_trials = TRIALS_BY_MODEL.get(model_name, 20)

    run_name = f"{model_name}__pca_{int(use_pca)}__optuna"
    with mlflow.start_run(run_name=run_name):
        mlflow.log_params(
            {
                "model_name": model_name,
                "use_pca": int(use_pca),
                "tuned": 1,
                "optuna_trials": n_trials,
                "cv_folds": cv.get_n_splits(),
                "seed": SEED,
            }
        )

        study = optuna.create_study(direction="maximize")
        study.optimize(lambda t: objective(t, model_name, use_pca), n_trials=n_trials)

        best_params = study.best_params
        cv_best_f1 = float(study.best_value)

        # Fit best + test
        best_pipe = build_pipeline_for_params(model_name, use_pca, best_params)
        best_pipe.fit(X_train, y_train)
        y_pred = best_pipe.predict(X_test)
        test_f1 = float(f1_score(y_test, y_pred))

        mlflow.log_metrics({"cv_f1_best": cv_best_f1, "test_f1": test_f1})
        mlflow.log_params({f"best__{k}": v for k, v in best_params.items()})

        # Save artifacts
        stamp = datetime.utcnow().strftime("%Y%m%d_%H%M%S")
        model_path = MODELS_DIR / f"{model_name}__pca_{int(use_pca)}__optuna.pkl"
        metrics_path = METRICS_DIR / f"{model_name}__pca_{int(use_pca)}__optuna.metrics.json"

        joblib.dump(best_pipe, model_path)

        metrics = {
            "model_name": model_name,
            "use_pca": bool(use_pca),
            "tuned": True,
            "optuna_trials": n_trials,
            "cv_f1_best": cv_best_f1,
            "test_f1": test_f1,
            "best_params": best_params,
            "model_path": str(model_path),
            "created_utc": stamp,
        }
        with open(metrics_path, "w", encoding="utf-8") as f:
            json.dump(metrics, f, indent=2)

        mlflow.log_artifact(str(model_path))
        mlflow.log_artifact(str(metrics_path))

        row = {
            "model_name": model_name,
            "use_pca": use_pca,
            "tuned": True,
            "cv_f1_best": cv_best_f1,
            "test_f1": test_f1,
            "model_path": str(model_path),
        }
        results.append(row)

        if best is None or test_f1 > best["test_f1"]:
            best = row

results_df = pd.DataFrame(results).sort_values(["test_f1"], ascending=False)
display(results_df)
print("Best (optuna):", best)

# Save best tuned model in the same filename used by the API
best_model_path = Path(best["model_path"])
best_pipe = joblib.load(best_model_path)

GLOBAL_BEST_PATH = MODELS_DIR / "global_best_model_optuna.pkl"
joblib.dump(best_pipe, GLOBAL_BEST_PATH)

print("✅ Saved global best (optuna) to:", GLOBAL_BEST_PATH)

# Optional: save summary
summary_path = METRICS_DIR / "summary_optuna.json"
summary = {
    "best_model_path": str(GLOBAL_BEST_PATH),
    "best_test_f1": float(best["test_f1"]),
    "n_experiments": len(results_df),
}
with open(summary_path, "w", encoding="utf-8") as f:
    json.dump(summary, f, indent=2)

mlflow.log_artifact(str(summary_path))

# Quick check
pred = best_pipe.predict(X_test)
print("Global best optuna test F1:", f1_score(y_test, pred))
# Out:
# 2025/12/19 20:50:22 INFO mlflow.tracking.fluent: Experiment with name 'airline_satisfaction_with_optuna' does not exist. Creating a new experiment.
# [I 2025-12-19 20:50:23,614] A new study created in memory with name: no-name-96e7ecfa-a4fc-4489-a74d-193e99e79c39
# [I 2025-12-19 20:50:28,150] Trial 0 finished with value: 0.8504176329961755 and parameters: {'solver': 'lbfgs', 'C': 0.0012717161160094024}. Best is trial 0 with value: 0.8504176329961755.
# [I 2025-12-19 20:50:31,997] Trial 1 finished with value: 0.8530778738600006 and parameters: {'solver': 'lbfgs', 'C': 13.679121661996287}. Best is trial 1 with value: 0.8530778738600006.
# [I 2025-12-19 20:50:34,937] Trial 2 finished with value: 0.8530828106682169 and parameters: {'solver': 'lbfgs', 'C': 0.41662217254022155}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:39,900] Trial 3 finished with value: 0.8530295679371822 and parameters: {'solver': 'liblinear', 'penalty': 'l1', 'C': 0.29853584548441897}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:46,668] Trial 4 finished with value: 0.8530702060722171 and parameters: {'solver': 'liblinear', 'penalty': 'l1', 'C': 0.4402299624027048}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:47,899] Trial 5 finished with value: 0.8530778738600006 and parameters: {'solver': 'lbfgs', 'C': 9.48104843379565}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:49,496] Trial 6 finished with value: 0.85303786049138 and parameters: {'solver': 'liblinear', 'penalty': 'l2', 'C': 0.30219417840595736}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:50,825] Trial 7 finished with value: 0.8528986083405814 and parameters: {'solver': 'lbfgs', 'C': 0.011957471509805301}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:52,083] Trial 8 finished with value: 0.852420631793349 and parameters: {'solver': 'lbfgs', 'C': 0.004378343584439736}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:53,752] Trial 9 finished with value: 0.8528131079400548 and parameters: {'solver': 'liblinear', 'penalty': 'l2', 'C': 0.017132661975385943}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:54,969] Trial 10 finished with value: 0.8530778738600006 and parameters: {'solver': 'lbfgs', 'C': 2.462052019490245}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:56,197] Trial 11 finished with value: 0.8530778738600006 and parameters: {'solver': 'lbfgs', 'C': 13.911183309416302}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:57,412] Trial 12 finished with value: 0.8530778738600006 and parameters: {'solver': 'lbfgs', 'C': 41.66374947574005}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:50:58,661] Trial 13 finished with value: 0.8530778738600006 and parameters: {'solver': 'lbfgs', 'C': 2.094924882856664}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20:51:00,228] Trial 14 finished with value: 0.8530297821278253 and parameters: {'solver': 'lbfgs', 'C': 0.054615201076382285}. Best is trial 2 with value: 0.8530828106682169.
# [I 2025-12-19 20
. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:40,291] Trial 12 finished with value: 0.8509076274841473 and parameters: {'solver': 'lbfgs', 'C': 0.018749128928767983}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:41,571] Trial 13 finished with value: 0.8508495882525544 and parameters: {'solver': 'lbfgs', 'C': 0.016083610304940134}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:42,791] Trial 14 finished with value: 0.8496154014850038 and parameters: {'solver': 'lbfgs', 'C': 0.0023976240802845955}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:44,139] Trial 15 finished with value: 0.8507852520641078 and parameters: {'solver': 'lbfgs', 'C': 0.04570843718311173}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:45,498] Trial 16 finished with value: 0.8509565181992722 and parameters: {'solver': 'lbfgs', 'C': 0.008338695388278193}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:46,712] Trial 17 finished with value: 0.850291127678781 and parameters: {'solver': 'lbfgs', 'C': 0.0034933430725290356}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:47,905] Trial 18 finished with value: 0.850721530953052 and parameters: {'solver': 'lbfgs', 'C': 0.09282203529370284}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:49,102] Trial 19 finished with value: 0.8507310481469832 and parameters: {'solver': 'lbfgs', 'C': 0.7793364703483715}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:50,302] Trial 20 finished with value: 0.8508879100294025 and parameters: {'solver': 'lbfgs', 'C': 0.00808093342876044}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:51,683] Trial 21 finished with value: 0.8508132076896906 and parameters: {'solver': 'lbfgs', 'C': 0.047735575982695455}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:52,975] Trial 22 finished with value: 0.8509097521090379 and parameters: {'solver': 'lbfgs', 'C': 0.012611943553336417}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:54,165] Trial 23 finished with value: 0.8468847195738084 and parameters: {'solver': 'lbfgs', 'C': 0.0010318112612273962}. Best is trial 1 with value: 0.8509576396186119.
# [I 2025-12-19 20:51:55,386] Trial 24 finished with value: 0.8509000253810157 and parameters: {'solver': 'lbfgs', 'C': 0.00793030559979573}. Best is trial 1 with value: 0.8509576396186119.
# C:\Users\nepal\AppData\Local\Temp\ipykernel_18376\1363233467.py:63: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   stamp = datetime.utcnow().strftime("%Y%m%d_%H%M%S")
# 🏃 View run logreg__pca_1__optuna at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1/runs/a6148e9ca6a447bd94d62d4040211d54
# 🧪 View experiment at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1
# [I 2025-12-19 20:51:57,703] A new study created in memory with name: no-name-daa96ced-a257-47f4-af1b-8eada1273e62
# [I 2025-12-19 20:51:58,877] Trial 0 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.0019106300209339548}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:00,152] Trial 1 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.0013485374937700445}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:01,262] Trial 2 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.005584189427653593}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:02,349] Trial 3 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.024181545369804772}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:03,447] Trial 4 finished with value: 0.849578249190045 and parameters: {'alpha': 1.3040372189107128}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:04,578] Trial 5 finished with value: 0.849578249190045 and parameters: {'alpha': 2.3445503564663155}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:05,679] Trial 6 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.603354906240014}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:06,770] Trial 7 finished with value: 0.849578249190045 and parameters: {'alpha': 1.282531010364318}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:07,918] Trial 8 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.648425443622316}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:09,020] Trial 9 finished with value: 0.8495576909466424 and parameters: {'alpha': 46.72381715745879}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:10,221] Trial 10 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.04387428710812991}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:11,389] Trial 11 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.0012885168835698384}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:12,605] Trial 12 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.0012976588287133151}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:13,708] Trial 13 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.010057907408039453}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:14,940] Trial 14 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.08171844398651304}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52:16,122] Trial 15 finished with value: 0.8495901908322552 and parameters: {'alpha': 0.004951172313421558}. Best is trial 0 with value: 0.8495901908322552.
# [I 2025-12-19 20:52
. Best is trial 3 with value: 0.8469223482099405.
# [I 2025-12-19 20:52:45,199] Trial 18 finished with value: 0.8469103362141513 and parameters: {'alpha': 0.0689001637214317}. Best is trial 3 with value: 0.8469223482099405.
# [I 2025-12-19 20:52:46,399] Trial 19 finished with value: 0.8469223482099405 and parameters: {'alpha': 0.3334871728475285}. Best is trial 3 with value: 0.8469223482099405.
# C:\Users\nepal\AppData\Local\Temp\ipykernel_18376\1363233467.py:63: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   stamp = datetime.utcnow().strftime("%Y%m%d_%H%M%S")
# 🏃 View run ridge__pca_1__optuna at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1/runs/81709c68d8a5409c932952a6dc804a72
# 🧪 View experiment at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1
# [I 2025-12-19 20:52:48,660] A new study created in memory with name: no-name-30b73a29-1dcd-4986-b54c-2e71479dbef7
# [I 2025-12-19 20:52:53,495] Trial 0 finished with value: 0.9277356263989953 and parameters: {'learning_rate': 0.031486260730097644, 'max_depth': 3, 'max_leaf_nodes': 212, 'min_samples_leaf': 172, 'l2_regularization': 1.2809991240945977, 'max_iter': 294}. Best is trial 0 with value: 0.9277356263989953.
# [I 2025-12-19 20:53:04,783] Trial 1 finished with value: 0.9545625695722759 and parameters: {'learning_rate': 0.020793644617702847, 'max_depth': 7, 'max_leaf_nodes': 210, 'min_samples_leaf': 108, 'l2_regularization': 4.424881463471817, 'max_iter': 495}. Best is trial 1 with value: 0.9545625695722759.
# [I 2025-12-19 20:53:15,049] Trial 2 finished with value: 0.9555327452009402 and parameters: {'learning_rate': 0.033143813446725935, 'max_depth': 7, 'max_leaf_nodes': 157, 'min_samples_leaf': 22, 'l2_regularization': 4.23746874916919e-06, 'max_iter': 294}. Best is trial 2 with value: 0.9555327452009402.
# [I 2025-12-19 20:53:26,094] Trial 3 finished with value: 0.9497495065083544 and parameters: {'learning_rate': 0.014746883251616041, 'max_depth': 8, 'max_leaf_nodes': 24, 'min_samples_leaf': 98, 'l2_regularization': 4.486342909638192e-06, 'max_iter': 418}. Best is trial 2 with value: 0.9555327452009402.
# [I 2025-12-19 20:53:37,541] Trial 4 finished with value: 0.9534133722774737 and parameters: {'learning_rate': 0.018382388830790505, 'max_depth': 10, 'max_leaf_nodes': 238, 'min_samples_leaf': 156, 'l2_regularization': 6.69045399461855, 'max_iter': 347}. Best is trial 2 with value: 0.9555327452009402.
# [I 2025-12-19 20:53:43,431] Trial 5 finished with value: 0.9415099535130989 and parameters: {'learning_rate': 0.16059275449430713, 'max_depth': 2, 'max_leaf_nodes': 173, 'min_samples_leaf': 127, 'l2_regularization': 0.02009318432170772, 'max_iter': 390}. Best is trial 2 with value: 0.9555327452009402.
# [I 2025-12-19 20:53:49,154] Trial 6 finished with value: 0.9546832777028971 and parameters: {'learning_rate': 0.04666548198108, 'max_depth': 8, 'max_leaf_nodes': 131, 'min_samples_leaf': 29, 'l2_regularization': 0.00011583377922847062, 'max_iter': 138}. Best is trial 2 with value: 0.9555327452009402.
# [I 2025-12-19 20:53:53,246] Trial 7 finished with value: 0.9350865658842155 and parameters: {'learning_rate': 0.13119400037130405, 'max_depth': 2, 'max_leaf_nodes': 206, 'min_samples_leaf': 173, 'l2_regularization': 3.952890142926929, 'max_iter': 233}. Best is trial 2 with value: 0.9555327452009402.
# [I 2025-12-19 20:53:57,509] Trial 8 finished with value: 0.9550181799453563 and parameters: {'learning_rate': 0.08122614516546434, 'max_depth': 6, 'max_leaf_nodes': 219, 'min_samples_leaf': 84, 'l2_regularization': 0.10762580217501601, 'max_iter': 147}. Best is trial 2 with value: 0.9555327452009402.
# [I 2025-12-19 20:54:06,601] Trial 9 finished with value: 0.9550155128915326 and parameters: {'learning_rate': 0.05624806230443271, 'max_depth': 5, 'max_leaf_nodes': 198, 'min_samples_leaf': 38, 'l2_regularization': 8.766250732939916, 'max_iter': 447}. Best is trial 2 with value: 0.9555327452009402.
# [I 2025-12-19 20:54:09,732] Trial 10 finished with value: 0.9551251353413488 and parameters: {'learning_rate': 0.26164579868040855, 'max_depth': 10, 'max_leaf_nodes': 93, 'min_samples_leaf': 64, 'l2_regularization': 2.7216898239362113e-06, 'max_iter': 237}. Best is trial 2 with value: 0.9555327452009402.
# [I 2025-12-19 20:54:13,212] Trial 11 finished with value: 0.9559993631844514 and parameters: {'learning_rate': 0.24673786450267013, 'max_depth': 10, 'max_leaf_nodes': 99, 'min_samples_leaf': 60, 'l2_regularization': 1.4643960707703043e-06, 'max_iter': 251}. Best is trial 11 with value: 0.9559993631844514.
# [I 2025-12-19 20:54:15,984] Trial 12 finished with value: 0.9554251748170154 and parameters: {'learning_rate': 0.29476669602046146, 'max_depth': 9, 'max_leaf_nodes': 96, 'min_samples_leaf': 12, 'l2_regularization': 0.00010817807944141207, 'max_iter': 258}. Best is trial 11 with value: 0.9559993631844514.
# [I 2025-12-19 20:54:20,416] Trial 13 finished with value: 0.9329584294849216 and parameters: {'learning_rate': 0.032863048736259025, 'max_depth': 4, 'max_leaf_nodes': 142, 'min_samples_leaf': 51, 'l2_regularization': 6.0908956082040476e-05, 'max_iter': 198}. Best is trial 11 with value: 0.9559993631844514.
# [I 2025-12-19 20:54:29,660] Trial 14 finished with value: 0.942020914541484 and parameters: {'learning_rate': 0.011065035256815101, 'max_depth': 6, 'max_leaf_nodes': 62, 'min_samples_leaf': 81, 'l2_regularization': 1.7381515328419967e-05, 'max_iter': 351}. Best is trial 11 with value: 0.9559993631844514.
# [I 2025-12-19 20:54:36,022] Trial 15 finished with value: 0.9569984057025416 and parameters: {'learning_rate': 0.09411354014935217, 'max_depth': 8, 'max_leaf_nodes': 147, 'min_samples_leaf': 16, 'l2_regularization': 0.0004849739479275872, 'max_iter': 303}. Best is trial 15 with value: 0.9569984057025416.
# [I 2025-12-19 20:54:40,038] Trial 16 finished with value: 0.9563554596047258 and parameters: {'learning_rate': 0.14412322883301557, 'max_depth': 9, 'max_leaf_nodes': 110, 'min_samples_leaf': 56, 'l2_regularization': 0.0016995582591229103, 'max_iter': 181}. Best is trial 15 with value: 0.9569984057025416.
# [I 2025-12-19 20:54:45,969] Trial 17 finished with value: 0.957330850076595 and parameters: {'learning_rate': 0.09780082790733909, 'max_depth': 8, 'max_leaf_nodes': 122, 'min_samples_leaf': 50, 'l2_regularization': 0.0008009357563081069, 'max_iter': 200}. Best is trial 17 with value: 0.957330850076595.
# [I 2025-12-19 20:54:49,999] Trial 18 finished with value: 0.956597638517648 and parameters: {'learning_rate': 0.08642306088692148, 'max_depth': 8, 'max_leaf_nodes': 174, 'min_samples_leaf': 39, 'l2_regularization': 0.001511011580537266, 'max_iter': 105}. Best is trial 17 with value: 0.957330850076595.
# [I 2025-12-19 20:54:55,599] Trial 19 finished with value: 0.9571419690269071 and parameters: {'learning_rate': 0.10332249018779524, 'max_depth': 7, 'max_leaf_nodes': 65, 'min_samples_leaf': 13, 'l2_regularization': 0.011198001875320515, 'max_iter': 338}. Best is trial 17 with value: 0.957330850076595.
# [I 2025-12-19 20:55:02,487] Trial 20 finished with value: 0.9556792560362304 and parameters: {'learning_rate': 0.06802077694475417, 'max_depth': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 141, 'l2_regularization': 0.02316856655312159, 'max_iter': 351}. Best is trial 17 with value: 0.957330850076595.
# [I 2025-12-19 20:55:07,829] Trial 21 finished with value: 0.9568017917761222 and parameters: {'learning_rate': 0.09564990069920676, 'max_depth': 7, 'max_leaf_nodes': 123, 'min_samples_leaf': 10, 'l2_regularization': 0.0005372835308610957, 'max_iter': 304}. Best is trial 17 with value: 0.957330850076595.
# [I 2025-12-19 20:55:12,937] Trial 22 finished with value: 0.9573509785980608 and parameters: {'learning_rate': 0.11375022013825241, 'max_depth': 9, 'max_leaf_nodes': 76, 'min_samples_leaf': 33, 'l2_regularization': 0.01163639356944018, 'max_iter': 322}. Best is trial 22 with value: 0.9573509785980608.
# [I 2025-12-19 20:55:16,487] Trial 23 finished with value: 0.9565368269370653 and parameters: {'learning_rate': 0.18786830320740566, 'max_depth': 9, 'max_leaf_nodes': 65, 'min_samples_leaf': 200, 'l2_regularization': 0.009830097450836217, 'max_iter': 381}. Best is trial 22 with value: 0.9573509785980608.
# [I 2025-12-19 20:55:21,337] Trial 24 finished with value: 0.9566567886124314 and parameters: {'learning_rate': 0.11593631282921225, 'max_depth': 7, 'max_leaf_nodes': 75, 'min_samples_leaf': 37, 'l2_regularization': 0.1467061043807539, 'max_iter': 325}. Best is trial 22 with value: 0.9573509785980608.
# C:\Users\nepal\AppData\Local\Temp\ipykernel_18376\1363233467.py:63: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   stamp = datetime.utcnow().strftime("%Y%m%d_%H%M%S")
# 🏃 View run hgb__pca_0__optuna at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1/runs/f086324ffb134e90ba82252e79635353
# 🧪 View experiment at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1
# [I 2025-12-19 20:55:28,404] A new study created in memory with name: no-name-2e1beb1d-db54-459f-b2d7-029955653c3c
# [I 2025-12-19 20:55:31,364] Trial 0 finished with value: 0.9182573103838412 and parameters: {'learning_rate': 0.13378591638763093, 'max_depth': 5, 'max_leaf_nodes': 152, 'min_samples_leaf': 106, 'l2_regularization': 8.450338583358269e-06, 'max_iter': 106}. Best is trial 0 with value: 0.9182573103838412.
# [I 2025-12-19 20:55:37,812] Trial 1 finished with value: 0.8779851465810526 and parameters: {'learning_rate': 0.02988391162698395, 'max_depth': 2, 'max_leaf_nodes': 195, 'min_samples_leaf': 93, 'l2_regularization': 0.19610015555448682, 'max_iter': 459}. Best is trial 0 with value: 0.9182573103838412.
# [I 2025-12-19 20:55:50,737] Trial 2 finished with value: 0.9145689952063162 and parameters: {'learning_rate': 0.012392040214111348, 'max_depth': 8, 'max_leaf_nodes': 154, 'min_samples_leaf': 146, 'l2_regularization': 0.5278440061224791, 'max_iter': 350}. Best is trial 0 with value: 0.9182573103838412.
# [I 2025-12-19 20:55:57,562] Trial 3 finished with value: 0.912897938266994 and parameters: {'learning_rate': 0.09928516921782718, 'max_depth': 3, 'max_leaf_nodes': 56, 'min_samples_leaf': 123, 'l2_regularization': 0.006810804900604656, 'max_iter': 425}. Best is trial 0 with value: 0.9182573103838412.
# [I 2025-12-19 20:56:04,316] Trial 4 finished with value: 0.935448629637228 and parameters: {'learning_rate': 0.18936169771569594, 'max_depth': 6, 'max_leaf_nodes': 135, 'min_samples_leaf': 193, 'l2_regularization': 0.0001730544039614087, 'max_iter': 337}. Best is trial 4 with value: 0.935448629637228.
# [I 2025-12-19 20:56:08,311] Trial 5 finished with value: 0.9092221112517735 and parameters: {'learning_rate': 0.08570670122567063, 'max_depth': 4, 'max_leaf_nodes': 148, 'min_samples_leaf': 110, 'l2_regularization': 2.4429532373729223e-05, 'max_iter': 182}. Best is trial 4 with value: 0.935448629637228.
# [I 2025-12-19 20:56:13,572] Trial 6 finished with value: 0.9348114566738287 and parameters: {'learning_rate': 0.28254513218725785, 'max_depth': 7, 'max_leaf_nodes': 201, 'min_samples_leaf': 74, 'l2_regularization': 4.81418914706287, 'max_iter': 233}. Best is trial 4 with value: 0.935448629637228.
# [I 2025-12-19 20:56:19,838] Trial 7 finished with value: 0.9325738514073251 and parameters: {'learning_rate': 0.22251026100067492, 'max_depth': 7, 'max_leaf_nodes': 16, 'min_samples_leaf': 90, 'l2_regularization': 1.1450037097900398e-05, 'max_iter': 391}. Best is trial 4 with value: 0.935448629637228.
# [I 2025-12-19 20:56:27,960] Trial 8 finished with value: 0.9323362816870769 and parameters: {'learning_rate': 0.280187768364125, 'max_depth': 4, 'max_leaf_nodes': 98, 'min_samples_leaf': 158, 'l2_regularization': 0.0003070115667641303, 'max_iter': 408}. Best is trial 4 with value: 0.935448629637228.
# [I 2025-12-19 20:56:33,322] Trial 9 finished with value: 0.9097430961086701 and parameters: {'learning_rate': 0.03674909628123869, 'max_depth': 6, 'max_leaf_nodes': 32, 'min_samples_leaf': 192, 'l2_regularization': 0.45591687031907013, 'max_iter': 195}. Best is trial 4 with value: 0.935448629637228.
# [I 2025-12-19 20:56:44,756] Trial 10 finished with value: 0.9364355952404981 and parameters: {'learning_rate': 0.05976669566214536, 'max_depth': 10, 'max_leaf_nodes': 95, 'min_samples_leaf': 16, 'l2_regularization': 0.0014526707778353156, 'max_iter': 295}. Best is trial 10 with value: 0.9364355952404981.
# [I 2025-12-19 20:56:57,759] Trial 11 finished with value: 0.9356238521390161 and parameters: {'learning_rate': 0.0482517762146714, 'max_depth': 10, 'max_leaf_nodes': 92, 'min_samples_leaf': 11, 'l2_regularization': 0.0020284070976133457, 'max_iter': 314}. Best is trial 10 with value: 0.9364355952404981.
# [I 2025-12-19 20:57:08,855] Trial 12 finished with value: 0.9358151504803243 and parameters: {'learning_rate': 0.05561793902050741, 'max_depth': 10, 'max_leaf_nodes': 85, 'min_samples_leaf': 16, 'l2_regularization': 0.0081099014401149, 'max_iter': 263}. Best is trial 10 with value: 0.9364355952404981.
# [I 2025-12-19 20:57:20,722] Trial 13 finished with value: 0.9250006885213808 and parameters: {'learning_rate': 0.020375222551372613, 'max_depth': 10, 'max_leaf_nodes': 85, 'min_samples_leaf': 16, 'l2_regularization': 0.014567238397290575, 'max_iter': 258}. Best is trial 10 with value: 0.9364355952404981.
# [I 2025-12-19 20:57:30,419] Trial 14 finished with value: 0.9341813874838317 and parameters: {'learning_rate': 0.06664058101138406, 'max_depth': 9, 'max_leaf_nodes': 59, 'min_samples_leaf': 47, 'l2_regularization': 0.0007928853607883607, 'max_iter': 289}. Best is trial 10 with value: 0.9364355952404981.
# [I 2025-12-19 20:57:46,613] Trial 15 finished with value: 0.9367928835000152 and parameters: {'learning_rate': 0.06028806521432649, 'max_depth': 9, 'max_leaf_nodes': 119, 'min_samples_leaf': 48, 'l2_regularization': 0.031896707502636054, 'max_iter': 500}. Best is trial 15 with value: 0.9367928835000152.
# [I 2025-12-19 20:58:04,735] Trial 16 finished with value: 0.9305509451164715 and parameters: {'learning_rate': 0.02267034594619731, 'max_depth': 8, 'max_leaf_nodes': 252, 'min_samples_leaf': 49, 'l2_regularization': 0.058131824160496934, 'max_iter': 466}. Best is trial 15 with value: 0.9367928835000152.
# [I 2025-12-19 20:58:15,102] Trial 17 finished with value: 0.9374127378210393 and parameters: {'learning_rate': 0.10193352138324081, 'max_depth': 9, 'max_leaf_nodes': 182, 'min_samples_leaf': 47, 'l2_regularization': 8.819629590081663e-05, 'max_iter': 486}. Best is trial 17 with value: 0.9374127378210393.
# [I 2025-12-19 20:58:23,863] Trial 18 finished with value: 0.9370719073741072 and parameters: {'learning_rate': 0.1309488136859816, 'max_depth': 8, 'max_leaf_nodes': 189, 'min_samples_leaf': 60, 'l2_regularization': 5.0638869058698444e-05, 'max_iter': 500}. Best is trial 17 with value: 0.9374127378210393.
# [I 2025-12-19 20:58:31,969] Trial 19 finished with value: 0.9359524442971988 and parameters: {'learning_rate': 0.137908414075912, 'max_depth': 8, 'max_leaf_nodes': 196, 'min_samples_leaf': 67, 'l2_regularization': 1.6051249168853985e-06, 'max_iter': 496}. Best is trial 17 with value: 0.9374127378210393.
# [I 2025-12-19 20:58:41,153] Trial 20 finished with value: 0.9357394153942888 and parameters: {'learning_rate': 0.13725991009462685, 'max_depth': 7, 'max_leaf_nodes': 243, 'min_samples_leaf': 35, 'l2_regularization': 7.57485662034214e-05, 'max_iter': 374}. Best is trial 17 with value: 0.9374127378210393.
# [I 2025-12-19 20:58:52,936] Trial 21 finished with value: 0.9372120236209709 and parameters: {'learning_rate': 0.09472976105503726, 'max_depth': 9, 'max_leaf_nodes': 177, 'min_samples_leaf': 60, 'l2_regularization': 1.7017250971800602e-06, 'max_iter': 498}. Best is trial 17 with value: 0.9374127378210393.
# [I 2025-12-19 20:59:04,541] Trial 22 finished with value: 0.9368748757713872 and parameters: {'learning_rate': 0.09331127047716395, 'max_depth': 9, 'max_leaf_nodes': 172, 'min_samples_leaf': 70, 'l2_regularization': 1.1248732502063052e-06, 'max_iter': 439}. Best is trial 17 with value: 0.9374127378210393.
# [I 2025-12-19 20:59:11,032] Trial 23 finished with value: 0.935004363685913 and parameters: {'learning_rate': 0.17422015744652192, 'max_depth': 9, 'max_leaf_nodes': 219, 'min_samples_leaf': 35, 'l2_regularization': 4.3688800180413614e-05, 'max_iter': 469}. Best is trial 17 with value: 0.9374127378210393.
# [I 2025-12-19 20:59:20,949] Trial 24 finished with value: 0.9364958558585551 and parameters: {'learning_rate': 0.10733275233919456, 'max_depth': 8, 'max_leaf_nodes': 174, 'min_samples_leaf': 61, 'l2_regularization': 4.569255279117883e-06, 'max_iter': 496}. Best is trial 17 with value: 0.9374127378210393.
# C:\Users\nepal\AppData\Local\Temp\ipykernel_18376\1363233467.py:63: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   stamp = datetime.utcnow().strftime("%Y%m%d_%H%M%S")
# 🏃 View run hgb__pca_1__optuna at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1/runs/1740c0d2db0e4678bf6004e67d7acfe8
# 🧪 View experiment at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1
# [I 2025-12-19 20:59:30,798] A new study created in memory with name: no-name-f5dfff51-70da-4843-9858-d28dfdd1ac71
# [I 2025-12-19 20:59:46,796] Trial 0 finished with value: 0.948415742458278 and parameters: {'n_estimators': 244, 'max_depth': 13, 'min_samples_split': 19, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.948415742458278.
# [I 2025-12-19 21:00:20,077] Trial 1 finished with value: 0.9462938443105248 and parameters: {'n_estimators': 564, 'max_depth': 21, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 0 with value: 0.948415742458278.
# [I 2025-12-19 21:00:38,941] Trial 2 finished with value: 0.9444398956368241 and parameters: {'n_estimators': 324, 'max_depth': 14, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 0 with value: 0.948415742458278.
# [I 2025-12-19 21:01:08,655] Trial 3 finished with value: 0.9530427867858 and parameters: {'n_estimators': 474, 'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 3 with value: 0.9530427867858.
# [I 2025-12-19 21:01:30,986] Trial 4 finished with value: 0.9496901277232996 and parameters: {'n_estimators': 353, 'max_depth': 24, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 3 with value: 0.9530427867858.
# [I 2025-12-19 21:01:53,238] Trial 5 finished with value: 0.9480442018455992 and parameters: {'n_estimators': 352, 'max_depth': 30, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 3 with value: 0.9530427867858.
# [I 2025-12-19 21:02:30,905] Trial 6 finished with value: 0.9510221427789597 and parameters: {'n_estimators': 522, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.9530427867858.
# [I 2025-12-19 21:04:00,308] Trial 7 finished with value: 0.9532812980649042 and parameters: {'n_estimators': 245, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 7 with value: 0.9532812980649042.
# [I 2025-12-19 21:04:30,543] Trial 8 finished with value: 0.9231115225440979 and parameters: {'n_estimators': 417, 'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 7 with value: 0.
 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 1 with value: 0.9231289109594712.
# [I 2025-12-19 21:36:16,560] Trial 10 finished with value: 0.9156759504574807 and parameters: {'n_estimators': 337, 'max_depth': 19, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.9231289109594712.
# [I 2025-12-19 21:40:40,199] Trial 11 finished with value: 0.9204441441777442 and parameters: {'n_estimators': 321, 'max_depth': 16, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 1 with value: 0.9231289109594712.
# [I 2025-12-19 21:45:53,732] Trial 12 finished with value: 0.9195038048984238 and parameters: {'n_estimators': 336, 'max_depth': 15, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 1 with value: 0.9231289109594712.
# [I 2025-12-19 21:52:29,808] Trial 13 finished with value: 0.9229366762264963 and parameters: {'n_estimators': 389, 'max_depth': 19, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 1 with value: 0.9231289109594712.
# [I 2025-12-19 22:01:18,934] Trial 14 finished with value: 0.923148925124449 and parameters: {'n_estimators': 584, 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 14 with value: 0.923148925124449.
# [I 2025-12-19 22:09:58,080] Trial 15 finished with value: 0.9237392088401647 and parameters: {'n_estimators': 566, 'max_depth': 21, 'min_samples_split': 13, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 15 with value: 0.9237392088401647.
# [I 2025-12-19 22:18:55,753] Trial 16 finished with value: 0.9235683176153288 and parameters: {'n_estimators': 584, 'max_depth': 22, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 15 with value: 0.9237392088401647.
# [I 2025-12-19 22:20:30,977] Trial 17 finished with value: 0.9153114186776781 and parameters: {'n_estimators': 582, 'max_depth': 22, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.9237392088401647.
# [I 2025-12-19 22:27:16,949] Trial 18 finished with value: 0.9172090978907708 and parameters: {'n_estimators': 547, 'max_depth': 13, 'min_samples_split': 16, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 15 with value: 0.9237392088401647.
# [I 2025-12-19 22:34:25,087] Trial 19 finished with value: 0.9214908555072509 and parameters: {'n_estimators': 435, 'max_depth': 30, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 15 with value: 0.9237392088401647.
# C:\Users\nepal\AppData\Local\Temp\ipykernel_18376\1363233467.py:63: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   stamp = datetime.utcnow().strftime("%Y%m%d_%H%M%S")
# 🏃 View run rf__pca_1__optuna at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1/runs/9ba7ce25660d4c08a65ef5295faebc2c
# 🧪 View experiment at: https://dagshub.com/Aayushnepal09/my-first-repo.mlflow/#/experiments/1
#   model_name  use_pca  tuned  cv_f1_best   test_f1  \
# 4        hgb    False   True    0.957351  0.959686
# 6         rf    False   True    0.954006  0.956487
# 5        hgb     True   True    0.937413  0.939292
# 7         rf     True   True    0.923739  0.927166
# 0     logreg    False   True    0.853111  0.855662
# 2      ridge    False   True    0.849590  0.852969
# 1     logreg     True   True    0.850958  0.852298
# 3      ridge     True   True    0.846922  0.849952
#
#                                           model_path
# 4  c:\Users\nepal\OneDrive\Desktop\airline_satisf...
# 6  c:\Users\nepal\OneDrive\Desktop\airline_satisf...
# 5  c:\Users\nepal\OneDrive\Desktop\airline_satisf...
# 7  c:\Users\nepal\OneDrive\Desktop\airline_satisf...
# 0  c:\Users\nepal\OneDrive\Desktop\airline_satisf...
# 2  c:\Users\nepal\OneDrive\Desktop\airline_satisf...
# 1  c:\Users\nepal\OneDrive\Desktop\airline_satisf...
# 3  c:\Users\nepal\OneDrive\Desktop\airline_satisf...
# Best (optuna): {'model_name': 'hgb', 'use_pca': False, 'tuned': True, 'cv_f1_best': 0.9573509785980608, 'test_f1': 0.959685569904548, 'model_path': 'c:\\Users\\nepal\\OneDrive\\Desktop\\airline_satisfaction_appp\\models\\hgb__pca_0__optuna.pkl'}
# ✅ Saved global best (optuna) to: c:\Users\nepal\OneDrive\Desktop\airline_satisfaction_appp\models\global_best_model_optuna.pkl
# Global best optuna test F1: 0.959685569904548
